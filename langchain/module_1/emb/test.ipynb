# %%
contextEMbedding = [0.0175026152,-0.00140379916,-0.0453943945,-0.00723418361,0.0659603253,0.0299317297,-0.0149749964,-0.0140927974,0.0208139177,0.031090647,-0.0207214281,0.0222649425,0.00708268723,0.00221660058,-0.03501454,-0.067277886,0.0505979732,0.0165194664,0.0370737687,0.0264239926,-0.0124685057,0.0165438391,0.0165319666,-0.0252538044,0.0299314577,-0.0525912,0.0129630826,-0.016770564,-0.0369776785,0.0462129861,-0.0401010364,0.0524911731,-0.0286058206,0.0204571225,0.00653628632,-0.0542016663,-0.00565457717,0.0134979896,-0.0317739,-0.019115679,0.0418470316,-0.0414099693,-0.030441476,0.000581194763,-0.0170552898,0.0491550341,-0.0284243487,0.0239084736,0.00552007463,-0.0431831889,-0.00882169511,-0.00852163136,0.0867663845,-0.0211358219,0.0214714184,-0.0111750746,0.0416754484,-0.0169310644,-0.00519083254,0.017366549,-0.00422811555,0.0338100232,0.0201706961,0.0365498252,-0.0244191661,-0.036726065,-0.0139140617,0.00216308655,0.0541993752,0.0326010063,0.00766952429,-0.0138102286,0.0325450785,0.0255898144,-0.00241105305,-0.121914871,0.00627928041,0.0643300787,0.0109775523,-0.033659175,0.0453611463,-0.0360417552,-0.0451258421,-0.0211566892,-0.0848895535,0.0247634817,0.0109502757,0.0240586959,0.0000796440581,-0.0184273086,-0.00189753086,0.0102930283,0.0603771098,-0.0448434204,-0.00963012688,0.0975368619,-0.021700833,-0.0465241149,0.0248199217,-0.0479772761,0.0183857698,-0.00558957318,-0.00782769546,0.00346505921,0.0510948487,0.00143705274,0.00413617864,0.0422867686,-0.0400310569,0.00852764864,-0.0318393148,0.0190250576,0.0144414753,0.00331946253,0.0249302648,-0.0368794948,0.0170483589,0.0863218457,0.0508588217,0.035882581,0.0399105549,-0.0040025413,0.0723111629,-0.0138628855,0.0189121142,0.00166919234,0.0147821633,0.0578142703,0.0459927283,-0.00765208714,-0.0442153811,-0.0024676316,-0.0301182345,0.00454691,0.0402745679,0.111916065,0.060099043,0.00800885,0.00598873897,0.00864688586,-0.007510514,0.0267397705,-0.0100825187,0.0203792136,0.0284477808,0.022241611,-0.0276148804,-0.0114761265,0.0478561372,-0.0312819891,-0.000945618202,0.0107539119,-0.0389135256,-0.0220393687,0.0771752521,0.0429849513,-0.0397830456,0.0291017573,-0.00883982051,-0.000201403964,0.00194778433,0.0278243516,0.0326754972,0.0423029661,-0.0679377913,0.00862506311,-0.0249650944,-0.0128992936,-0.00694039417,0.023433255,-0.0133432467,0.0555050187,-0.0352067,-0.0319530554,0.0199713912,-0.0552851297,0.0471718349,0.0177575927,-0.0423621759,0.0205553565,-0.0108390963,-0.0557952635,0.0038788612,0.0093786763,0.00618803687,-0.047017619,0.0814544335,-0.00714580901,-0.00328346551,0.0355838649,-0.0106682247,-0.00180406473,-0.0568317249,-0.01839724,-0.0252747498,0.0376251303,0.0230780113,-0.00432755519,0.0208312683,-0.0577801727,-0.0303617287,0.0506661683,-0.0133779692,0.0202262979,0.0515361242,-0.0206737984,0.0459825583,-0.0201593302,-0.0234344471,0.0514848083,-0.0258874986,0.0475645438,-0.0235944539,0.0086534,0.0129280416,-0.0366223305,0.0332605354,0.0119895609,0.0396175794,-0.0521687753,0.00913576,0.0426163152,0.00440370804,-0.00838929694,-0.0172202569,0.0305719189,-0.0574795157,0.0202094074,0.0463674515,-0.056390658,-0.00450885482,0.0660514235,-0.00910036,0.012451713,0.086114496,0.0104085719,0.0338412412,0.0624208786,0.0441611037,0.0724733248,-0.033391837,0.0259280037,0.0530829318,0.0221708473,-0.0756963119,-0.000266590388,-0.0286844168,0.0532804243,0.0364553258,0.0384715572,-0.0179250557,-0.0324192382,-0.0202566795,0.0301020835,-0.0263071395,0.0247064494,-0.0751136318,-0.00368505809,-0.0123552475,0.0186832342,0.0906294435,0.0114995725,-0.0163160488,0.00260124053,0.00618361589,-0.0286140814,0.00097080064,-0.0875454098,-0.0218638908,0.0355605818,0.0203424171,-0.0276835617,0.0118532693,0.0192990229,0.0600108653,0.00175405515,-0.0103419246,0.00545007037,0.029957423,-0.0443085767,0.0134684164,0.0263020918,0.029178733,-0.038881883,0.00701398449,-0.0250688214,-0.0925900415,-0.0335290693,-0.00616580434,-0.0131668821,-0.0257901661,-0.0733528,0.00371610816,-0.0547574461,-0.0434424952,0.00641605165,0.00363930105,0.048324544,0.0194474924,-0.0222776812,0.00543570658,-0.0367211439,0.0505271889,-0.0488027334,0.0350609981,0.0160288941,-0.0433914736,-0.0632441267,0.0296477973,0.00567217777,0.0287730843,0.013401567,-0.0473554507,0.0332052782,0.0532352664,0.00779306795,-0.0156962015,0.0448918715,-0.0204789955,-0.00114101672,0.0158349387,0.0624853298,0.0466594808,-0.0126104,0.0205085129,0.0554682352,-0.0349598825,-0.0027781825,-0.0155712953,-0.00925100222,-0.0198747087,0.00717876526,-0.0523885489,-0.0501441322,-0.0192394834,0.0617912039,-0.0496050082,-0.00125809782,-0.0505176373,-0.00441044336,-0.020573644,0.0095146494,-0.0436513834,-0.0164840128,0.0232785437,-0.00299681188,0.0118426438,0.0371472165,0.0941236541,0.0337992236,-0.000564487127,0.0547270142,-0.040292386,0.0309378617,-0.0182546098,-0.0186243355,-0.0108385943,-0.0229771864,0.0492845327,-0.0407762975,-0.000879925967,-0.000765442732,-0.014868916,-0.0404256247,-0.0211495832,-0.02316254,0.0218958035,0.0429375097,-0.0204259027,0.0526107326,0.046578262,-0.00946561527,0.0508800894,-0.0494254045,0.0191940609,-0.0248575751,-0.0378523134,-0.0651664212,0.0145933777,0.0275805276,-0.0261995438,-0.00646763062,0.0317311324,0.0364646763,0.0219261479,0.0145848161,0.0568651967,0.0433015265,-0.0313514508,0.0284703057,-0.0529055484,0.0195554662,0.0866776928,-0.0077386857,0.0205486398,-0.0457282029,-0.00721700629,-0.0668304265,0.039723184,0.0139139462,-0.0124750044,-0.0572752021,-0.0615388975,-0.0188466255,-0.0618601963,0.0103848344,0.0129138129,-0.0185293015,-0.0216103923,-0.0223874636,0.0274240635,0.0149077279,0.00870208256,-0.055108197,-0.0106382789,0.00735885417,0.046368476,-0.00246780878,0.0165016446,0.044073265,-0.0201650243,0.0169073641,-0.00995602831,-0.00989817549,-0.0835441947,-0.0172542315,0.0161815565,0.00897897407,0.0224207509,0.0379594974,0.0467953086,0.0111883292,0.0111667356,-0.0240864735,-0.0277822,-0.047749076,0.00970058143,0.0546862781,-0.0273764282,0.0261009969,0.0305423029,0.00786634441,-0.00824098103,-0.018301988,-0.0253119115,-0.0566548668,-0.020029474,0.00890421588,0.0237869285,-0.0917955935,0.0304092467,-0.0854583457,-0.00257090409,-0.0458961166,-0.0435979925,-0.0239818599,0.0572634786,0.0548626706,-0.0196016412,-0.0121040894,0.0520930961,-0.0168730784,-0.0146170137,-0.0856131762,0.0456596501,0.00107179536,0.0479861125,-0.0231012907,-0.0103343707,0.00028144088,0.0143202534,-0.00898477435,-0.000528619275,-0.0608502291,-0.0414006189,-0.0117142098,-0.0773513168,0.0559251,-0.0242404491,-0.0185422916,-0.00779370172,0.0191829074,-0.00511723105,0.00061934808,0.00565687474,0.050345704,-0.061517898,-0.00717204111,-0.042185124,0.0724930093,-0.00794437435,-0.0457287133,-0.0444240458,-0.0300494675,-0.024491027,-0.00879620109,0.00925917737,0.0548848175,0.0451643169,0.0314971469,-0.0163520221,0.013050301,0.0287714135,-0.0472565033,0.0250669643,-0.047689639,0.0251886733,0.0265920479,-0.0130257,0.00514505478,-0.00704352604,0.000964935694,-0.0342217349,0.0409179553,0.033346884,-0.0248112325,-0.0228227582,-0.00647080038,0.00567636546,-0.00878961664,-0.0102127828,0.0249224938,-0.0795722678,-0.00908001233,0.0248487238,-0.0445336401,-0.0119996,0.0402496122,-0.0821414813,0.0219910685,-0.0377675742,0.0466076098,-0.027465146,-0.00190642965,0.000349684939,-0.0204582904,0.0312447,0.00352092762,-0.0261447243,0.0102274092,0.0277069807,0.0100663109,0.0384454541,0.0501301,-0.0158592816,0.00789344683,-0.0110622877,-0.0630658045,-0.00868664589,0.00432301126,0.0261053108,0.00273729791,0.0391098149,-0.0233731661,-0.0160120428,-0.0500735939,-0.0243946444,-0.0298669133,0.00572879286,-0.0650452673,0.0111187175,-0.00490626041,0.00093027344,-0.00120857416,0.0794823095,-0.00117378286,0.014685302,-0.0158385728,0.0390409119,-0.0418359973,0.00526301935,-0.0158879273,0.0579851046,-0.0164413918,0.0762519911,-0.0424316414,-0.0649445504,-0.0325265266,-0.00273706065,0.0239324477,0.0446810275,-0.00908474438,-0.0019755594,0.0589768402,-0.035850022,-0.0406494737,0.0557970852,0.0248337146,0.0336531475,0.0191561319,-0.0436821431,0.0185097158,-0.00146255502,0.00441081217,0.00764579698,-0.0112447143,0.0178154148,-0.0659714937,-0.0585689656,-0.0197851639,0.012982931,-0.0426065102,0.0242196284,-0.0232231412,0.0902579725,0.0416680165,0.0421994254,-0.00765963364,0.0169229154,0.0527063496,-0.0168295633,-0.0333331488,-0.0258843284,0.00572388293,-0.0665346831,-0.0490287803,0.108230397,-0.0171487425,-0.0254430957,-0.0671360791,0.0231562052,-0.0177871231,0.0342223048,0.0163891427,0.0265935361,0.013013632,-0.00457601389,-0.0286917109,0.0791407,0.00531446375,0.00762999104,0.0602011196,-0.00704004755,0.0329827182,-0.0532505102,0.0254471302,-0.00621739123,0.0157081708,0.0412681065,0.00873991661,-0.0540258922,-0.000236073945,0.00441272743,0.0290302318,-0.0166249517,0.0303142555,0.0136838257,-0.0987563357,-0.0278578717,-0.0349155217,-0.0480234213,-0.00281445403,0.00246719131,-0.000515623309,0.0109832287,0.0194667149,0.00850133132,-0.021160068,0.047834076,-0.0249522142,-0.0338485725,-0.00445283297,-0.024598334,0.0236092266,-0.0254819468,-0.000417293602,-0.0547758564,-0.0826045275,-0.0434755832,0.0279460978,-0.0903170109,0.0185867548,0.104086764,0.00963642262,0.0519921035,0.0498873815,0.0209580194,0.0131912557,-0.00310020358,0.00309236,0.000551218574,-0.00343254069,-0.0433216691,-0.0237989798,-0.00798833929,0.0345678031,0.00187077955,0.0128348488,-0.0197063293,-0.0210163984,-0.0136063099,-0.0358169749,-0.00657264423,0.0141818207,0.0636267066,0.0344046652,-0.00319961924,-0.0378543,-0.059618108,0.050300274,-0.00870020315,-0.0389479585,0.00603190903,0.0383798406,0.0283499975,-0.0343125798,0.0459874496,0.0872975141,0.0254941247,0.0786435,0.040223565,-0.0362267829,-0.0102838194,0.0223982446,0.00245230645,-0.0831654891,-0.00331516727,0.030357521,-0.019706456,0.0309672952,0.0369141959,0.0451747663,0.0157603081,-0.0381923057,-0.0135216266,0.0516005903,-0.0287807304,-0.00646258565,-0.0071312557,0.0185643043,0.0748411268,-0.024730932,-0.0143031543,0.0098006418,-0.0308381617,0.0688873827,0.0138976686,0.0219799131,-0.0304568745,-0.0445474237,-0.041203618,0.0181223564,-0.0213432275,0.0305332392,0.0185320918,-0.0473365672,-0.0320657231,-0.00546794524,0.0359323546,-0.0428815931,-0.0572663844,0.0329517797,-0.0318783335,-0.0253371261,0.0394170918,-0.0132796196,0.0267307,-0.0206121504,-0.00142719818,0.00909319799,0.00153172109,-0.0186856519,-0.0114199016,-0.000824628572,0.0405579209,0.00532235904,-0.0443134755,-0.0183469784]
queryEMbedding1 = [0.032993596,-0.0244969297,-0.0604787655,-0.00796878524,0.0788476318,0.025040742,0.0128378347,-0.0279552285,-0.00466318429,0.0681691542,-0.00963335298,0.025529,0.0102111241,0.0215197522,-0.0233504958,-0.0497426838,0.0328509249,0.0274775345,0.0413160697,-0.0114450874,0.00901471,0.0280339755,-0.0109028127,0.0105006406,0.0306120962,-0.0334815606,0.0109228306,-0.034177646,-0.0601713434,-0.00234484,-0.0428574,0.0545051582,-0.0240337607,0.0121760201,0.017544277,-0.0627914369,0.00736705307,0.0246127043,-0.00411933847,0.0212901253,0.0475273393,-0.0222119112,-0.0362331,-0.00564132631,-0.013403439,0.0390023142,-0.0365458466,0.0327652954,0.0117215058,-0.0296103582,0.00845626555,0.0219005849,0.0730709657,-0.0428074338,0.0112559982,-0.0601932816,0.0332713723,-0.0326183215,0.0030836449,0.0228268895,-0.00791165326,0.0221179724,0.0204158574,0.0117405737,-0.0168659482,-0.0613553673,0.0105822654,0.0101622669,0.0654847622,0.0156001896,-0.0118852109,-0.01535221,0.0519646518,0.00466998806,0.0180804357,-0.112647697,0.00358778122,0.0591944642,0.0159823336,-0.0207833089,0.0365882106,-0.0404185504,-0.0524441898,-0.0253070518,-0.071383968,0.0305842776,0.00704649277,-0.0102366377,0.0206148736,0.0179565512,-0.0139874872,-0.0103090266,0.0550346635,-0.0452467687,0.00653512962,0.0942655876,-0.0308777839,-0.0313079022,0.0488879,-0.0295421835,0.0204017907,-0.0414343327,-0.0309763271,0.0170176532,0.0576620139,-0.00193877658,0.0333049148,0.0427241921,-0.0181975067,0.0313625,-0.0328367278,0.00775665976,0.0339943171,0.0225570127,0.0279826969,-0.0494725704,0.00985882431,0.0526220761,0.0359406359,0.0491133817,0.0674863681,-0.0454070903,0.0966195241,-0.0198129099,0.0487997644,-0.00517273694,-0.013128384,0.0640429184,0.016192453,0.00475613121,-0.0329889804,-0.0354709178,-0.0496520512,0.0224325,0.0615063906,0.0998181328,0.0424474515,0.00649470231,0.0321422927,0.00485849287,-0.00794954877,0.0273918267,-0.0169155933,0.0457324833,-0.0112248603,0.0488012396,-0.0508006848,0.0015738887,0.0636433065,-0.0365786068,-0.0374569371,-0.00291152857,-0.0437623784,-0.0188901704,0.0536787771,0.0337103903,-0.0275247581,0.0237496588,0.0105612827,-0.0082441438,0.0179826934,0.0478178896,0.0287273768,0.0181395579,-0.0279070456,-0.0266554542,-0.00873508584,-0.00174238312,0.00325345015,-0.00469952542,-0.0351517648,0.0484908633,-0.0426378697,-0.00616441853,0.0112391906,-0.0519677848,0.0575567707,0.00229923078,-0.0259862691,-0.0038649966,0.0187110268,-0.0543156974,0.00746003259,0.0209937245,0.014443242,-0.0609925352,0.0655185878,-0.00780274626,-0.0170109328,-0.00332620903,-0.0186444763,-0.00323955365,-0.0584757328,-0.045446869,-0.0147977257,0.0400722586,0.00622610142,-0.0125144,0.0069281077,-0.0517001748,-0.0253708456,0.0511604249,0.0127171651,0.00886879489,0.0517767407,-0.0272957422,0.0596841201,-0.0428747423,-0.0323084779,0.024837235,-0.0215729102,0.0591102466,-0.0227054972,0.0060808342,0.0328945965,-0.0105449352,0.0373257026,0.0174470041,0.0272022784,-0.0145488139,-0.0213091504,0.000533578044,-0.0199984387,0.00542753516,0.00215051952,0.0410988294,-0.0255398918,-0.00649482664,0.0115140835,-0.0470102169,-0.00318305567,0.0645228401,0.0154583184,-0.0285689421,0.104914322,-0.000134458503,0.0119022941,0.0334986746,0.00796819758,0.0445561074,-0.0435027704,0.0288929287,0.0330622345,0.0563037507,-0.0849269703,-0.0152501101,-0.0433447473,0.0180841312,0.0290959254,0.0630704314,-0.0172608886,-0.0527892895,-0.0102595901,-0.00944059435,-0.0781166852,0.00282766251,-0.0579311661,0.0439566411,-0.0407400429,0.0131985331,0.0814530253,0.0105375918,-0.0151069621,-0.0228325631,-0.0097174542,-0.0175313428,0.0221353304,-0.0890875757,0.00170344545,0.0170711279,0.0248636454,-0.0537716635,0.0322463252,0.01237112,0.0336062275,0.0175698958,-0.0160815846,0.0462693684,0.000140986886,-0.059747044,0.0174470376,0.0286415871,0.0322925784,-0.0419283248,0.00202309294,-0.0544259772,-0.0469764769,-0.0428099073,0.0073786159,-0.0384837277,0.00240389397,-0.0756705105,-0.00193893013,-0.0488052219,-0.0274966937,0.00135206699,0.00102025934,0.0427277833,0.0217746254,-0.0236204956,-0.00887746084,-0.029990701,0.0272090696,-0.0635963231,0.0266819801,0.00795380119,-0.0329923853,-0.0647309497,0.0305617321,0.0114987344,0.0161622241,0.0125859044,-0.0297561679,-0.00148560258,0.039793089,0.033330977,-0.0208394155,0.0142528731,-0.0107846521,0.0396171622,-0.00314607308,0.0662483349,0.0422283411,-0.0465313457,-0.00385459722,0.041094061,-0.0130671458,0.000631329196,-0.0168352723,-0.0135684172,-0.0315865874,0.0386470295,-0.0796073228,-0.0265348572,-0.0227114018,0.0603941306,-0.071425572,-0.00527100265,-0.0681115091,-0.0110953553,0.0107028065,0.0284651294,-0.040728841,-0.0277453829,0.0221276563,-0.0315326825,-0.00863064453,0.0084351534,0.0768275112,0.0500797,0.0189251378,0.0557500124,0.00409742771,0.0444147736,-0.0168027859,-0.0177672058,0.0352280922,-0.0365198255,0.0373016074,-0.0426012948,-0.00611513155,-0.0026218337,-0.0111392597,-0.0316619575,-0.000462200725,-0.0226309914,0.0319330767,0.012539384,-0.0154516594,0.0496683978,0.0264340863,-0.0334793553,0.0582113713,-0.0335506238,-0.0136414804,0.00879874825,-0.0654662475,-0.048348397,0.0146060698,0.00326474,0.0153849283,0.00390512845,0.0183099154,0.0116236601,0.0110378601,-0.00156773068,0.0455115624,0.0231402144,-0.0218474828,0.041638881,-0.0587441921,0.0364406183,0.0764010772,-0.00746880658,0.0371071473,-0.0280380622,0.0268891156,-0.0446092449,0.0270256773,0.0138221607,-0.0408180095,-0.0835672542,-0.0472318195,0.0152899139,-0.0709994808,-0.0259237252,0.0102248061,0.00107675407,-0.0275100619,-0.00877715088,0.0257466212,-0.0120756347,0.0160913952,-0.0616285652,-0.00587683124,0.0104901642,0.0646148548,-0.037683,-0.0209291819,0.0611292347,-0.0245625451,0.0137541229,-0.0143730659,-0.015986437,-0.0653093085,-0.0331928432,0.0114485156,0.02014005,-0.00104226894,0.0177759062,0.0564301573,0.0115275243,-0.0118680913,-0.0298745316,-0.0088234432,-0.0643578246,0.0143069439,0.0369690806,-0.0106540425,0.0053001293,0.033679653,0.00227754819,0.00761719607,-0.0246586259,-0.0354352705,-0.0394227505,0.00350840925,-0.0148934955,0.0010014365,-0.0828155,0.0351912156,-0.0829029456,0.0153668821,-0.0577908643,-0.0841138288,-0.0051920712,0.0531901717,0.0583840497,-0.0106039476,-0.00340592582,0.019450672,-0.0141571844,-0.0155396806,-0.10192284,0.0447831787,0.0189281125,0.015865447,-0.00691843918,0.0182857625,0.00971668493,0.00667789625,-0.0467720442,-0.0209464859,-0.0386047326,-0.0369215123,-0.00181383535,-0.0939048752,0.0714478344,-0.0180992689,-0.0189905055,0.00498344423,0.0269770045,-0.012608787,0.00728529226,-0.0105974171,0.0199125018,-0.0358463,-0.0377098806,-0.0310456976,0.033683572,0.0118923588,-0.0432055667,-0.0125110336,-0.0378845781,-0.0298280288,0.0181646943,-0.0175204594,0.0533514023,0.0604018047,0.0271086302,-0.0302718785,-0.0165864788,0.0190323032,-0.0152062504,0.0499977358,-0.0512338057,0.00695584109,0.0000228820118,0.000502297073,-0.0106055988,0.0273995847,0.0114645,-0.0250687208,0.0428142324,0.0274767783,-0.0203241445,-0.00828839187,0.0116251679,0.0110768424,-0.0242595095,-0.0122566093,0.00302399648,-0.0894502252,-0.00478756148,0.0032199542,-0.0277912784,-0.00658918731,0.0101840943,-0.0737641677,0.0312961936,-0.0242072381,0.0535740741,-0.0343418643,-0.00514934538,0.0244430583,-0.0185182299,0.0410944,0.00815074611,-0.0300147198,0.00578975538,0.0624296106,-0.0192544255,0.0441519395,0.0234648436,-0.0143259335,0.0213473532,-0.00691003026,-0.0586882979,-0.0210092179,0.0312486812,0.00900016911,0.033155445,0.0327486359,-0.0328556672,-0.0130066387,-0.0400441252,-0.0206043534,0.00934930332,-0.0000306295078,-0.0579098389,0.00417161919,-0.0457722619,-0.0106454855,0.0381185822,0.0478284955,-0.0114627294,0.000839901215,-0.0322544686,0.0531641208,-0.00807212479,0.00856545847,0.013779127,0.0423190556,0.0148968576,0.050011,-0.000747015059,-0.0824522302,-0.0162944682,0.000925350876,0.00580575271,0.0381441116,-0.0355979875,-0.000125771941,0.0573151223,-0.0151690198,-0.00879684091,0.0909592509,0.0520259291,0.01231978,0.0267621018,-0.0701237097,0.0129281,-0.019772293,0.0180999991,0.0217765495,-0.0120554324,0.000525725132,-0.0487687066,-0.0326227359,-0.0360033847,0.0244977251,-0.00338553218,0.00824874174,-0.0173647366,0.0826690793,0.0335822292,0.0149994316,0.00543171447,0.0230054259,0.0558785,-0.0152491173,-0.0143425325,-0.00316469558,-0.00935938,-0.0305176415,-0.0376223139,0.0988602862,-0.0305920057,-0.0189766809,-0.0540966205,-0.00149077468,-0.00716345338,0.0110778585,-0.0366239212,0.0302571151,0.0376547724,-0.00283206254,-0.024119867,0.0656582788,0.0221453,0.0191352163,0.102907866,-0.0228585266,0.022803802,-0.0319230743,-0.0063159531,-0.0286594164,0.0246150941,0.0342940465,-0.0158095639,-0.0574837029,-0.026356576,0.0153930131,0.0190111026,0.000359296217,0.083400555,0.0415680595,-0.0777934417,-0.0519233458,-0.00670070434,-0.0113553051,-0.00150878541,0.00232410734,0.00149223953,0.0120624239,0.0297868438,-0.00281547662,-0.0649363771,0.0192889869,-0.0275136903,-0.0397534408,0.00291881,-0.0266748518,0.00778772775,-0.00215000659,-0.00847307127,-0.0421606787,-0.0983238891,-0.0327971689,0.00809482299,-0.0825750828,0.0143827591,0.0809486061,-0.00172208692,0.0476948693,0.0170827787,0.00464751897,0.0038194668,0.0246505,0.0307999719,0.0266041216,-0.000401753758,-0.0348852,0.00380720617,0.00486189919,0.0573095083,0.0197923984,0.0088400254,-0.0388428122,-0.053034462,-0.000873003039,-0.0402969234,-0.0250393078,0.0503344163,0.0284709949,0.0420226827,-0.0014398006,-0.0115010655,-0.0206411537,0.0316907354,-0.0111460667,-0.0423190407,-0.00198523072,0.0294058137,0.0232255477,-0.00274831592,0.0370136574,0.0634503663,0.047405,0.0618517734,0.0227683168,-0.0247600581,-0.0287253652,0.017405821,0.0132837715,-0.0669852793,-0.00335797155,0.0270743538,-0.0403040387,0.0629786402,0.0338131562,0.0237974804,0.0450137928,-0.0292589068,-0.0489504933,0.0854921639,-0.0453472659,-0.0251675528,-0.02273448,-0.00693844259,0.0825423598,-0.00645314297,-0.0118628219,0.0201059189,-0.0258535445,0.104637943,0.0701742396,0.0336243361,-0.0292978454,-0.0587080978,-0.0345736668,0.000568077492,0.00139258476,0.034014497,0.0124862678,-0.0224139318,-0.0152184321,-0.0261389259,0.0150283128,-0.0652141348,-0.0475700572,0.0315796547,-0.0388859659,0.0309476,0.04443492,-0.00856800098,-0.0115072494,-0.000634322816,0.00231286045,0.0127792656,-0.018719025,-0.0140745491,-0.0160050504,-0.000652856485,0.0357761607,0.0112302424,0.0120094419,0.000076973156]
queryEMbedding = [0.026624484, -0.0236578789, -0.0578143783, -0.00890050456, 0.0781346634, 0.0241850317, 0.0116596464, -0.033865273, -0.00248288, 0.0638686791, -0.00921905879, 0.0237436816, 0.000525353069, 0.0217259545, -0.0202330947, -0.0555157624, 0.0301031657, 0.026078213, 0.0454178825, -0.0101875942, 0.0115313688, 0.0322063938, -0.0139831, 0.0156461429, 0.0290923081, -0.0362812914, 0.00826042704, -0.0299335644, -0.0542351119, -0.0101913279, -0.0489604771, 0.0490760393, -0.0270158015, 0.0125748431, 0.0219249837, -0.0549449772, 0.00459702034, 0.0305144489, -0.00467016827, 0.0192730185, 0.0461305045, -0.0274923164, -0.0360281, -0.0119262068, -0.0182241015, 0.0458058, -0.0395233966, 0.0240436327, 0.00927416328, -0.0328443944, 0.0124106091, 0.0248282366, 0.0788257942, -0.0451708, 0.00895142276, -0.0592316128, 0.0312018115, -0.0310150739, 0.00216972898, 0.0141894482, -0.00512800599, 0.0202471949, 0.0180551913, 0.0123575116, -0.0234706234, -0.0638819486, 0.0129166422, 0.00557265803, 0.0686550885, 0.0159643516, -0.00744362595, -0.0206874125, 0.0549778454, -0.000803088362, 0.00157672726, -0.120782897, 0.00316302897, 0.0611207858, 0.0154845938, -0.017489817, 0.0367840677, -0.040064238, -0.0451098979, -0.0339247882, -0.075631924, 0.0240548942, 0.00439776573, -0.00946314074, 0.0233068783, 0.0234435089, -0.0120442351, -0.0148023488, 0.0514595509, -0.0450437367, 0.00185754674, 0.0924224705, -0.0284541864, -0.0333309807, 0.0438422412, -0.0252503026, 0.0199719276, -0.0408251807, -0.0296119247, 0.0163721386, 0.0579421856, -0.00706254225, 0.0405293107, 0.040140368, -0.0187664088, 0.0304672513, -0.0341100506, 0.012743324, 0.0418054648, 0.0164600685, 0.0255663879, -0.0456851833, 0.0139180543, 0.060987372, 0.0340229608, 0.0474895835, 0.0692530498, -0.0534524918, 0.0921593383, -0.0176378842, 0.0512988791, -0.00349547295, -0.0130406907, 0.0705272406, 0.0302791614, -0.00169166934, -0.035512317, -0.0368593112, -0.0529720075, 0.0160547718, 0.0692314059, 0.099920027, 0.0396696478, 0.00814224221, 0.03026703, 0.00257728272, -0.00262489775, 0.028781753, -0.0215942748, 0.0435400195, -0.00810695, 0.0423128232, -0.0499436818, 0.00785667356, 0.0646810159, -0.0272143986, -0.0315180719, -0.00731754582, -0.0458349697, -0.0124024684, 0.0529792681, 0.0284988079, -0.0237996224, 0.022560304, 0.0130262487, -0.0027339228, 0.0156251919, 0.0415965691, 0.0298375804, 0.0148715517, -0.0243793838, -0.0187419131, -0.0145474803, 0.000233100713, 0.00838273298, -0.00250597764, -0.0303864, 0.0499075092, -0.0497581773, 0.00172901386, 0.0136632072, -0.0501915552, 0.0570821427, -0.000089488989, -0.0309801605, -0.00225631171, 0.0183197018, -0.0445193723, 0.00437455159, 0.0239806548, 0.0125762895, -0.0562038459, 0.0676041394, -0.00270404457, -0.00942819659, -0.00613555, -0.0223016161, 0.000607795606, -0.0650110319, -0.0529839806, -0.0122418506, 0.0447622351, 0.00641638041, -0.0125718294, 0.0019753417, -0.0507752784, -0.0256560426, 0.0583942458, 0.0075866268, 0.0189719237, 0.0474993773, -0.0220466424, 0.0516783185, -0.0462269336, -0.0327359401, 0.0238917749, -0.0261136424, 0.0597864576, -0.0259607844, 0.00980281737, 0.032624919, -0.014148904, 0.0352635346, 0.0172562432, 0.0299176835, -0.0103850421, -0.0213025324, 0.00584623497, -0.0179535598, 0.00618609367, -0.00204740674, 0.0422392339, -0.0225212853, -0.00502189901, 0.0130470414, -0.0455355309, 0.00360620464, 0.0666119456, 0.0078228442, -0.0265931, 0.103433594, 0.000923363084, 0.010671299, 0.0376973115, 0.00719989697, 0.0457570106, -0.0418101363, 0.0356010273, 0.0323277749, 0.0571142547, -0.080644995, -0.0104898764, -0.0405982211, 0.0283927508, 0.0226540081, 0.0620305389, -0.0166774355, -0.0531557873, -0.0124106845, -0.0118079903, -0.0800012, -0.00315677747, -0.0551751927, 0.0341188125, -0.0383322574, 0.0116211651, 0.0841885805, 0.0140408166, -0.0235118642, -0.0211396907, -0.0074256463, -0.0081599867, 0.013225982, -0.0829141736, 0.000374247204, 0.0165578611, 0.0244688429, -0.0458579473, 0.0326999612, 0.0157853812, 0.0252417177, 0.01766067, -0.0115781892, 0.0466798618, -0.0045320387, -0.0616467148, 0.0213345531, 0.0228623711, 0.0310875103, -0.0519282, 0.00627120677, -0.0474675447, -0.0465301648, -0.0377075784, 0.000854112965, -0.0392487124, -0.0048828437, -0.0742483214, -0.000929615286, -0.0475243032, -0.0198022332, -0.00391282234, -0.00215405133, 0.0409719646, 0.0161037724, -0.0186503548, -0.00306203985, -0.038291283, 0.0286618453, -0.0603998378, 0.0351272672, 0.00750647904, -0.0279295277, -0.0693287775, 0.027355453, 0.013190004, 0.0190384388, 0.0204559416, -0.0281449445, -0.0028481388, 0.0413432494, 0.025103597, -0.0278100409, 0.0146447122, -0.011921701, 0.0399912447, 0.00227472745, 0.065647468, 0.0393565856, -0.0425716192, 0.00344803068, 0.0396171473, -0.0121014165, -0.00600386411, -0.0241819378, -0.0111138271, -0.0279309433, 0.0384008102, -0.0764236674, -0.0207101777, -0.0260608923, 0.0500412472, -0.0634957626, -0.00660655741, -0.0664469674, -0.00926931854, 0.00728221564, 0.0315439738, -0.0468613878, -0.0314176232, 0.0271483324, -0.0367322527, -0.0129920701, 0.0162795968, 0.0761993229, 0.0487481616, 0.0229675, 0.0586207546, 0.00697065098, 0.035733249, -0.0187790953, -0.0152207166, 0.0309502352, -0.0379247814, 0.0278600343, -0.0442239, -0.00272854022, -0.00442586886, -0.00585884228, -0.0245449543, 0.00607346743, -0.0216100346, 0.0324974507, 0.0108326636, -0.0209256466, 0.0510373637, 0.0255263876, -0.0355996266, 0.0577556677, -0.0319462605, -0.0122504961, 0.0125055704, -0.0621302463, -0.0438206159, 0.0162823815, -0.00244420627, 0.02033359, 0.00403191661, 0.0198243298, 0.0104719643, 0.0137189357, -0.00266637467, 0.0525495224, 0.0233735815, -0.0182053708, 0.0361088514, -0.0564679, 0.0381589569, 0.0780629665, 0.00172032, 0.0359077416, -0.0210554712, 0.0244938, -0.0429526679, 0.0302589685, 0.0177330878, -0.0448804535, -0.0775573924, -0.053922, 0.0183650721, -0.0736797452, -0.0324770734, 0.011500231, -0.000641682826, -0.0249587614, -0.0143269105, 0.0304166116, -0.0127414241, 0.0166585315, -0.0636672452, -0.00281948433, 0.00941001158, 0.0655277669, -0.0320383199, -0.0282964855, 0.0564872026, -0.0311261248, 0.0198327843, -0.0202998538, -0.0195136424, -0.0551196374, -0.0245646741, 0.0162989609, 0.0128890015, -0.0049433331, 0.0183633398, 0.054440733, 0.012120585, -0.00347462972, -0.0193166081, -0.013115854, -0.0641357154, 0.0173991136, 0.0409651846, -0.0131448954, -0.00231089722, 0.0318181142, 0.0029913031, 0.0112810498, -0.0277942736, -0.0376799889, -0.0465321392, 0.00997581, -0.0213561747, 0.00122941739, -0.0803651586, 0.0376774035, -0.0863832, 0.0156988762, -0.0576762483, -0.0820098445, -0.00943707302, 0.0522740558, 0.0557471439, -0.00944189355, -0.00556475483, 0.0244376343, -0.00953298248, -0.0107459752, -0.0958149955, 0.0379660316, 0.0163178835, 0.0197663065, -0.00942876376, 0.0201222748, 0.0202014148, 0.00814391, -0.0516161807, -0.0252233669, -0.0326707847, -0.0397560559, -0.0104712341, -0.101217836, 0.0739901662, -0.00935991388, -0.0207583439, 0.0147292363, 0.02683842, -0.0181903075, 0.00201867078, -0.00267947582, 0.0205977336, -0.0392390415, -0.0401595, -0.0267774612, 0.0277442709, 0.0154211149, -0.0510431193, -0.0176341608, -0.0415056, -0.0214834567, 0.0206608549, -0.0188214201, 0.0517104827, 0.0577514321, 0.0272105336, -0.0307720099, -0.0214571394, 0.0237205531, -0.00256984867, 0.0477788523, -0.0519048311, 0.0119955055, 0.00266726851, 0.00458176667, -0.0132539803, 0.0328043699, 0.011375824, -0.0176561233, 0.0466669649, 0.0263862144, -0.0226110369, -0.00496859569, 0.0180199202, 0.00271675107, -0.020414969, -0.0204169657, 0.00310245086, -0.088581115, -0.00587574, 0.00539008, -0.0336626545, 0.00194840843, 0.00625539571, -0.0755670145, 0.0319776833, -0.0303469636, 0.0533135049, -0.0354246385, -0.00710209878, 0.0274955425, -0.00727721537, 0.0443400629, 0.0108378837, -0.0309772305, 0.00116031431, 0.0648448542, -0.016855536, 0.0426757075, 0.0259312019, -0.0164259523, 0.0211898014, -0.00236834167, -0.0507240295, -0.0182809364, 0.0266362745, 0.0119132968, 0.0360649154, 0.0311597846, -0.0242850855, -0.0104671735, -0.0475366749, -0.0139342789, -0.00161773874, -0.00151766278, -0.0570441075, 0.00120862236, -0.0431750305, -0.00918040238, 0.0353865437, 0.0482068, -0.0163096134, -0.00104257069, -0.0335620567, 0.0555911697, -0.00651892321, 0.00482414477, 0.00371303456, 0.0451917574, 0.00989124738, 0.0529053807, -0.00270093326, -0.0889553651, -0.0156832412, 0.00676210225, 0.0061111832, 0.0394557938, -0.0388352945, -0.000550088473, 0.0637121648, -0.0171242598, -0.00194702973, 0.0830281, 0.0489667729, 0.00859440584, 0.0223057102, -0.0613264255, 0.00938689429, -0.0178858303, 0.018004939, 0.0135707892, -0.0151866311, 0.00147766853, -0.0450421236, -0.027390264, -0.0314299315, 0.0284195188, 0.00249669584, 0.0112031559, -0.0198529419, 0.0892481729, 0.0344663523, 0.0149654364, 0.0154436268, 0.0258377064, 0.0607608259, -0.00991385, -0.00845537707, -0.00221082685, -0.00873519666, -0.0323255956, -0.0414532907, 0.0997548103, -0.029646853, -0.0211861543, -0.0646023378, -0.00889318436, -0.00844662, 0.0106608737, -0.0449689552, 0.0254940894, 0.0335238799, 0.00163831457, -0.024408469, 0.0645346269, 0.0180017985, 0.017337637, 0.0957044959, -0.0278669596, 0.0235734303, -0.0293065608, -0.00280698296, -0.0244120751, 0.018706996, 0.0337898023, -0.011603565, -0.064368993, -0.0248620734, 0.0202643443, 0.0131897451, 0.00526776956, 0.0810622349, 0.0435776301, -0.0769746378, -0.0441744775, -0.00600982597, -0.00618860917, -0.00225880882, -0.00155859103, 0.00902803242, 0.0070655439, 0.0296149869, -0.00446945429, -0.0627298, 0.0267391857, -0.0317840166, -0.0472237207, 0.00188288873, -0.0267813411, 0.00875904225, -0.00608283142, -0.0156838559, -0.0395812765, -0.104935803, -0.0382091664, 0.00558873964, -0.0845726952, 0.0123740966, 0.0825539827, -0.00202409574, 0.0493661687, 0.0110950507, 0.00854625739, 0.00381886284, 0.0135474866, 0.0367115922, 0.0372657925, -0.00423238054, -0.0339887403, 0.00461148471, 0.000362220919, 0.0536718331, 0.0277787596, 0.00710959733, -0.0455541536, -0.0551324561, -0.000670900219, -0.0334709585, -0.0241015665, 0.0508414358, 0.0261472296, 0.0366616063, -0.00665584626, -0.0131246457, -0.0224426016, 0.0261098929, -0.0208143592, -0.0421768501, -0.00293519208, 0.0305479746, 0.0228590202, -0.00118055474, 0.0369166732, 0.0599064231, 0.0514896251, 0.0620491058, 0.0223073848, -0.031282153, -0.0333842635, 0.0207046475, 0.00843018107, -0.0734896436, -0.00282080239, 0.0267076381, -0.043297749, 0.0695678219, 0.0337346345, 0.0215777345, 0.0415705368, -0.0290420987, -0.0458614975, 0.0868148208, -0.0336242579, -0.0260850396, -0.0294387657, -0.00588133419, 0.0764378607, -0.00900696125, -0.0137632731, 0.0159796029, -0.0284138359, 0.103583351, 0.0679506063, 0.0269462317, -0.0314503498, -0.0546548404, -0.0296370033, 0.00115769892, -0.00344004785, 0.0240909513, 0.0159351099, -0.0246321689, -0.0153837791, -0.0286636781, 0.0176949371, -0.0597322658, -0.0424201936, 0.035113927, -0.0374850444, 0.0290930811, 0.0423060507, -0.014353944, -0.0130279316, -0.000835414743, 0.000397947268, 0.0129827866, -0.0262035262, -0.0133003052, -0.0246099345, -0.00292548118, 0.0350981504, 0.00726251211, 0.0129091442, -0.00275555393]
import numpy as np

consine_similarity = np.dot(queryEMbedding,contextEMbedding)/(np.linalg.norm(queryEMbedding)*np.linalg.norm(contextEMbedding))
print(consine_similarity)
# Out:
# 0.852743925472165

# %%
contextEMbedding =[0.007234088145196438, -0.009645924903452396, -0.014838860370218754, 0.003494228469207883, 0.036310866475105286, 0.043535176664590836, -0.0037064782809466124, 0.000734407571144402, 0.032415151596069336, 0.020828936249017715, 0.028828993439674377, 0.013135071843862534, 0.008995845913887024, -0.016137385740876198, -0.05337081849575043, -0.05621862784028053, 0.03696331009268761, 0.01353372447192669, 0.02552039921283722, 0.02047847770154476, -0.0033966240007430315, 0.016521023586392403, 0.01764756627380848, -0.05348286032676697, 0.02795756794512272, -0.06912374496459961, 0.013053025119006634, -0.008437358774244785, -0.03938871994614601, 0.0760454460978508, -0.04755980521440506, 0.05330042168498039, -0.030838405713438988, 0.01344369351863861, -0.01321704126894474, -0.056390468031167984, -0.006131630390882492, 0.012243133038282394, -0.03328300267457962, 0.004887089598923922, 0.026832107454538345, -0.03103615529835224, -0.027427807450294495, -0.050320036709308624, 0.009013697504997253, 0.03924855217337608, -0.005556547548621893, 0.025432808324694633, 0.005191753152757883, -0.048417918384075165, -0.03006676211953163, -0.032828349620103836, 0.09165220707654953, -0.01970803551375866, 0.031691208481788635, -0.01214821171015501, 0.014224322512745857, 0.0026247401256114244, 0.004187081474810839, 0.0036174387205392122, 0.022800056263804436, 0.04609711840748787, -0.002795739332213998, 0.05706692487001419, -0.012600917369127274, -0.00975748524069786, -0.008681473322212696, 0.0010868802201002836, 0.06741932779550552, 0.029457036405801773, 0.029106663540005684, 0.013118612580001354, 0.026732858270406723, 0.01942538097500801, -0.03698286786675453, -0.09315332025289536, 0.015770087018609047, 0.07582320272922516, 0.01055912859737873, -0.03907085210084915, 0.027288885787129402, -0.018042435869574547, 0.014049973338842392, -0.016294633969664574, -0.07874715328216553, 0.04515935108065605, 0.01766267418861389, 0.043641235679388046, -0.02837575599551201, -0.008412151597440243, 0.019126595929265022, 0.005587202496826649, 0.008007890544831753, -0.05206618830561638, -0.010642287321388721, 0.06547676026821136, 0.000402876699808985, -0.04238197207450867, 0.00031813993700779974, -0.05046997219324112, 0.022566383704543114, -0.005426364950835705, 0.04257556051015854, -0.01613878645002842, 0.03455360233783722, 4.838406675844453e-05, 0.005118913482874632, 0.040937479585409164, -0.05372622236609459, 0.004116680473089218, -0.02227073907852173, 0.02554645575582981, 0.0069844042882323265, -0.0167031642049551, 0.011533328332006931, -0.03328055143356323, 0.010721161030232906, 0.09415852278470993, 0.039017800241708755, 0.03726455569267273, 0.013289043679833412, 0.015147914178669453, 0.056954275816679, -0.000688914384227246, 0.008492227643728256, 0.006219083908945322, 0.023281697183847427, 0.059820178896188736, 0.06728670746088028, 0.012331215664744377, -0.04342976585030556, 0.015465836971998215, 0.009140708483755589, 0.006494096480309963, 0.007112784311175346, 0.10133031755685806, 0.09066258370876312, 0.01983238384127617, 0.005802427884191275, -0.0036653070710599422, -0.0409114845097065, 0.02111680433154106, -0.017181748524308205, 0.015598435886204243, 0.030862197279930115, -0.037340227514505386, 0.026946447789669037, -0.044280242174863815, 0.0048247952945530415, -0.027953308075666428, 0.012551642954349518, -0.00871275458484888, -0.030446238815784454, 0.006400064565241337, 0.07845223695039749, 0.07945998758077621, -0.030522644519805908, 0.01319088600575924, 0.008100386708974838, -0.01176129188388586, 0.029209917411208153, 0.04153544083237648, 0.031239086762070656, 0.019200054928660393, -0.08147864043712616, 0.02124306932091713, -0.004974300507456064, -0.005735046695917845, -0.024558434262871742, 0.009895607829093933, -1.1507888302730862e-05, 0.04064872860908508, -0.01971292495727539, -0.02059924229979515, 0.007628063205629587, -0.08315622061491013, 0.0474451407790184, 0.01677580550312996, -0.041544973850250244, 0.03331692889332771, -0.02920995093882084, -0.06244685500860214, -0.023665128275752068, -0.02186458371579647, 0.014902026392519474, -0.014001429080963135, 0.07260540872812271, -0.0208903718739748, 0.005723798647522926, 0.03203006833791733, -0.001143406960181892, -0.016540978103876114, -0.032738540321588516, 0.010621351189911366, -0.02243489772081375, 0.05230848118662834, 0.009757149033248425, -0.007055474910885096, 0.019753146916627884, -0.05216880142688751, -0.04082965850830078, 0.04986733943223953, 0.003535355906933546, 0.022427156567573547, 0.046073995530605316, -0.0382876843214035, 0.03672491014003754, -0.014101184904575348, 0.0009095400455407798, 0.05261645466089249, -0.034571923315525055, 0.03636251389980316, -0.03531796857714653, 0.00785314105451107, -0.005443234462291002, -0.014414101839065552, 0.060098834335803986, 0.037037644535303116, 0.018759004771709442, -0.05215265974402428, 0.03146803751587868, 0.06277234852313995, 0.012870615348219872, -0.013839734718203545, -0.008465263992547989, 0.001091670012101531, -0.06577449291944504, 0.04683729261159897, 0.029312843456864357, -0.08213207125663757, -0.003066953970119357, 0.03629075363278389, -0.021735738962888718, -0.00372324394993484, 0.06740707159042358, 0.02212546579539776, 0.03997436538338661, 0.05856972187757492, 0.03861827403306961, 0.07235603034496307, -0.025262832641601562, 0.023653030395507812, 0.07726943492889404, 0.017057012766599655, -0.050413910299539566, 0.03579035401344299, 0.0007671971106901765, 0.010789264924824238, 0.032867126166820526, 0.010207976214587688, -0.06141556799411774, -0.018279878422617912, 0.008249361999332905, 0.06833194196224213, -0.0005399751826189458, 0.03747916594147682, -0.10157730430364609, -0.022744696587324142, -0.006712887901812792, 0.022489160299301147, 0.11002052575349808, 0.01844879239797592, -0.015706628561019897, 0.015335282310843468, -0.014534611254930496, -0.02028125710785389, 0.00125564681366086, -0.05972054973244667, -0.04645075649023056, 0.0372079499065876, 0.02714923582971096, -0.05416235700249672, 0.035834696143865585, 0.033706482499837875, 0.04553570598363876, 0.008033591322600842, -0.017469532787799835, -0.037592172622680664, 0.023845378309488297, -0.047003936022520065, 0.008033974096179008, 0.021750597283244133, 0.008534720167517662, -0.04053635522723198, -0.004338668659329414, -0.020908648148179054, -0.09255209565162659, 0.005158182233572006, 0.012210117653012276, 0.0012797174276784062, -0.027154788374900818, -0.07194648683071136, -0.027770649641752243, -0.04197947680950165, -0.04982468858361244, -0.0005399411893449724, 0.006207294296473265, 0.05253389850258827, 0.033789608627557755, 0.018170876428484917, 0.002140376716852188, 0.003678885055705905, 0.020612964406609535, -0.031268246471881866, 0.058208949863910675, 0.0028064160142093897, -0.03152085468173027, -0.057496801018714905, 0.004300134256482124, -0.00426511513069272, 0.03187577798962593, -0.004684010520577431, -0.04352065175771713, 0.04314829409122467, 0.05365055426955223, -0.0060372077859938145, -0.031619325280189514, 0.07449903339147568, -0.024066533893346786, -0.011444199830293655, 0.02034025266766548, 0.0676400437951088, 0.04250899702310562, -0.010214222595095634, 0.042521100491285324, 0.031532078981399536, -0.06956898421049118, 0.0032495493069291115, 0.011063857935369015, -0.04427143931388855, -0.013068038038909435, -0.006792924366891384, -0.04296509176492691, -0.048623036593198776, 0.01163712702691555, 0.06145842373371124, -0.006252345163375139, 0.02522210404276848, -0.03452439606189728, 0.005641285330057144, -0.00838406104594469, 0.0005346477846615016, -0.027655983343720436, -0.017684124410152435, 0.03144901990890503, -0.0044365087524056435, 0.061608221381902695, 0.014462736435234547, 0.09941579401493073, 0.007038390263915062, -0.011683819815516472, 0.05503218248486519, -0.060032546520233154, -0.0005261419573798776, -0.021903876215219498, -0.02459074929356575, -0.007609908003360033, -0.0037236472126096487, 0.07390117645263672, -0.044340912252664566, -0.029135623946785927, -0.005652459338307381, 0.0024051943328231573, -0.01593695767223835, -0.04009406641125679, -0.009244476445019245, 0.04778030142188072, 0.046631358563899994, -0.04262484610080719, 0.02938326820731163, 0.041066352277994156, 0.004678012803196907, 0.01950559765100479, -0.001089473720639944, -0.0071802278980612755, -0.05232297629117966, -0.02904624491930008, -0.053313981741666794, 0.0011708636302500963, 0.04176557436585426, -0.02754039317369461, -0.01395188458263874, 0.015403052791953087, 0.060372307896614075, 0.03419007360935211, 0.01584838517010212, 0.04934995248913765, 0.042352259159088135, 0.004488736856728792, 0.0199445653706789, 0.001976259518414736, -0.00322636472992599, 0.09918790310621262, 0.0031555532477796078, 0.013457836583256721, -0.01851225085556507, -0.01011027954518795, -0.05085457116365433, 0.022310905158519745, -0.022186920046806335, -0.0062874434515833855, -0.03111732378602028, -0.06635776162147522, -0.05091330036520958, -0.028865553438663483, -0.030657103285193443, -0.031191222369670868, -0.024822566658258438, -0.0066034384071826935, -0.025697609409689903, 0.037867262959480286, 0.049342431128025055, 0.017508797347545624, -0.04459994658827782, -0.01621074602007866, 0.01250382512807846, 0.04182041063904762, 0.0080048106610775, 0.05479570850729942, 0.026136422529816628, 0.01219960767775774, 0.03398996964097023, -0.01647881790995598, -0.020567629486322403, -0.03977036848664284, -0.00205531669780612, -0.016597986221313477, -0.016020555049180984, 0.023852722719311714, 0.05592033639550209, 0.036505769938230515, 0.014740659855306149, 0.0280661191791296, -0.016830235719680786, -0.04183502495288849, -0.05348970368504524, 0.022432342171669006, 0.039725858718156815, -0.022291306406259537, 0.045487117022275925, -0.021027859300374985, 0.0313243605196476, 0.004097806755453348, 0.011694269254803658, -0.04732599854469299, -0.06351863592863083, -0.03158297389745712, -0.013680811040103436, 0.031377095729112625, -0.10787007212638855, 0.01235897559672594, -0.09175261110067368, 0.017784271389245987, -0.021780725568532944, -0.028309497982263565, -0.04703500121831894, 0.06654278934001923, 0.02499152161180973, -0.014872425235807896, -0.019838085398077965, 0.04563814774155617, -0.008283155038952827, -0.026310842484235764, -0.057155124843120575, 0.02971433289349079, -0.004087232984602451, 0.07410501688718796, -0.03555557131767273, 0.014562305994331837, -0.0340777263045311, 0.021301986649632454, 0.004629175644367933, 0.026147836819291115, -0.02485780045390129, -0.05104554072022438, 0.02564687840640545, -0.07894479483366013, 0.044254716485738754, -6.314227357506752e-05, -0.013737604953348637, -0.013401598669588566, -0.004641049075871706, 0.03037438727915287, -0.014885998331010342, 0.02645806409418583, 0.03743806853890419, -0.047506220638751984, -0.013961050659418106, -0.023539770394563675, 0.08015300333499908, -0.04140850156545639, -0.03294394910335541, -0.04532032087445259, -0.009919121861457825, -0.002381234662607312, -0.011443235911428928, 0.022264612838625908, 0.04763880744576454, 0.024099836125969887, 0.03489914909005165, -0.006878590676933527, 0.026168029755353928, 0.04535096511244774, -0.04290259629487991, -0.005091875791549683, -0.03792279213666916, 0.0426933690905571, -0.004116914700716734, -0.02569732815027237, 0.01570504531264305, -0.004400426056236029, -0.006038685794919729, -0.014614386484026909, 0.03279472514986992, -0.0015056933043524623, 0.02191155031323433, -0.027156727388501167, 0.009751502424478531, 0.008268817327916622, -0.021146833896636963, -0.005588508676737547, 0.029259152710437775, -0.07918417453765869, -0.006166007835417986, 0.02851482294499874, -0.05996044725179672, 0.015725059434771538, 0.06785283237695694, -0.06884431838989258, 0.01921750232577324, -0.020178092643618584, 0.048124104738235474, -0.025558533146977425, 0.002676056930795312, -0.039235737174749374, -0.05183115229010582, 0.030533993616700172, -0.005883529782295227, -0.010260732844471931, 0.0274928230792284, 0.018168285489082336, 0.010859424248337746, 0.03643874451518059, 0.03394925966858864, 0.0023158397525548935, 0.0027658469043672085, 0.005974871106445789, -0.07735968381166458, -0.0024123250041157007, 0.007987004704773426, 0.033954985439777374, -0.030880166217684746, 0.01915091462433338, -0.014291560277342796, -0.022603880614042282, -0.059408850967884064, -0.03940197080373764, -0.02109757997095585, -0.017795227468013763, -0.07129915803670883, 0.011395582929253578, -0.03196109086275101, -0.001800044672563672, -0.0449482686817646, 0.08247001469135284, 0.016203107312321663, 0.01795237325131893, 0.006130486726760864, 0.028393825516104698, -0.033059027045965195, 0.031113581731915474, -0.01599225588142872, 0.06873825937509537, -0.028442258015275, 0.07227817922830582, -0.03654158487915993, -0.03925013542175293, -0.02149095945060253, 0.005672704894095659, 0.03328908979892731, 0.033051908016204834, 0.021416055038571358, 0.0032149995677173138, 0.03213739022612572, -0.0488385409116745, -0.01456244196742773, 0.02029671147465706, -0.022589964792132378, 0.04900890588760376, 0.005885554943233728, -0.02133164554834366, 0.025697169825434685, 0.0011841333471238613, 0.012590539641678333, 0.0022247035522013903, 0.003238539444282651, -0.018465446308255196, -0.07564645260572433, -0.07189279794692993, -0.017765840515494347, 0.020606230944395065, -0.045313894748687744, 0.06633554399013519, -0.025310121476650238, 0.06466174870729446, 0.02641262486577034, 0.0683884397149086, -0.009274599142372608, -0.01993599720299244, 0.005120739806443453, -0.009799015708267689, -0.0036747753620147705, -0.011045754887163639, 0.012927909381687641, -0.06592465937137604, -0.032383032143116, 0.07802531123161316, -0.02188771404325962, -0.018235906958580017, -0.06498795002698898, 0.03260154277086258, -0.041379932314157486, -0.009509516879916191, 0.04271690174937248, 0.042964037507772446, 0.013507849536836147, 0.03431595489382744, -0.02662094123661518, 0.05988207459449768, -0.009432155638933182, -0.03215016797184944, 0.04454826936125755, 0.010169776156544685, 0.013560255989432335, -0.04858192801475525, 0.03634119778871536, 0.003234892850741744, -0.026256076991558075, 0.03649209067225456, 0.0034911034163087606, -0.07611919939517975, 0.030281811952590942, 0.030308745801448822, 0.018105855211615562, -0.008167214691638947, 0.02914608269929886, 0.009096533991396427, -0.1007622480392456, 0.007231296971440315, -0.01310775987803936, -0.07881777733564377, -0.0018784282729029655, 0.011950836516916752, 0.021432088688015938, -0.008454060181975365, 0.004627919290214777, 0.013516833074390888, 0.012363743036985397, 0.04426265135407448, -0.013720911927521229, -0.034976862370967865, 0.02510475367307663, -0.0002209216181654483, 0.02658001147210598, -0.03937589004635811, 0.014686672948300838, -0.0418093316257, -0.03609615936875343, -0.05329056829214096, 0.05560876801609993, -0.0786164179444313, 0.016047267243266106, 0.10807062685489655, 0.025968870148062706, 0.0359564945101738, 0.06352590024471283, -0.0032294339034706354, 0.008689225651323795, -0.02349783480167389, 0.01402304507791996, -0.028291525319218636, -0.018848516047000885, -0.02907978557050228, -0.027625838294625282, -0.007670973427593708, 0.005282392725348473, -0.020783256739377975, 0.01580062508583069, -0.003817944787442684, 0.0023200062569230795, -0.006147103384137154, -0.022619767114520073, -0.014700692147016525, -0.037003275007009506, 0.09684430062770844, -0.00483627337962389, 0.001287063118070364, -0.03262660279870033, -0.052606139332056046, 0.06398864090442657, -0.01445030514150858, -0.020606163889169693, 0.008194961585104465, 0.019359787926077843, 0.005954567342996597, -0.029929907992482185, 0.025008095428347588, 0.06792373210191727, 0.01176967192441225, 0.06295270472764969, 0.05881236866116524, -0.03635673224925995, -0.03798331320285797, 0.011296548880636692, 0.011269559152424335, -0.054570313543081284, -0.009763197973370552, 0.011889914982020855, -0.019161343574523926, 0.028381744399666786, 0.034054648131132126, 0.032686345279216766, 0.031047841534018517, -0.05680214986205101, 0.016129417344927788, 0.018186582252383232, -0.03170062229037285, 0.022288473322987556, 0.003102219197899103, 0.01998668909072876, 0.07073041051626205, -0.016314122825860977, -0.0201825350522995, 0.005088290199637413, -0.031359218060970306, 0.03498927131295204, -0.016400331631302834, 0.014640314504504204, -0.041197456419467926, -0.025558199733495712, -0.037462640553712845, 0.004497438669204712, -0.029217995703220367, 0.03764352202415466, 0.014635193161666393, -0.052937764674425125, -0.021118301898241043, 0.023871107026934624, 0.024339430034160614, -0.014513008296489716, -0.06799204647541046, 0.04551253095269203, -0.027447884902358055, -0.04784680902957916, 0.02749926596879959, -0.01768040470778942, 0.05036891624331474, -0.011994997970759869, 0.007749252021312714, 0.013898211531341076, -0.0073158578015863895, -0.005761938635259867, -0.023253019899129868, 0.010980967432260513, 0.04323788732290268, 0.013119247741997242, -0.05333865061402321, -0.011268865317106247]
queryEMbedding = [-0.0018112075049430132, -0.05158242583274841, -0.015305813401937485, -0.013748006895184517, 0.05227283388376236, 0.02118963561952114, 0.013048425316810608, -0.025235198438167572, 0.0009403556468896568, 0.03192758187651634, 0.049958497285842896, 0.031153788790106773, 0.0378972589969635, -0.023723073303699493, -0.013762928545475006, -0.03121877647936344, 0.02710173837840557, 0.004141505341976881, 0.024398108944296837, -0.01743444986641407, 0.005658379755914211, 0.03870006278157234, -0.02285677194595337, -0.01356804184615612, 0.023924654349684715, -0.03867824003100395, 0.03264307230710983, -0.048280663788318634, -0.05974872037768364, 0.039382677525281906, -0.07496301829814911, 0.039440128952264786, -0.04456796497106552, 0.0035710446536540985, 0.019661033526062965, -0.0735306441783905, 0.037282709032297134, 0.04003029689192772, 0.01123698242008686, 0.025416232645511627, 0.038835279643535614, -0.006487101782113314, -0.026974467560648918, -0.0591210201382637, 0.021461350843310356, 0.02948998101055622, 0.01963207870721817, 0.01748226210474968, 0.011862644925713539, -0.04224551469087601, -0.009241924621164799, 0.025119120255112648, 0.06194509565830231, -0.03906245157122612, 0.037872832268476486, -0.05874963104724884, 0.02866116538643837, -0.0014041890390217304, -0.022575944662094116, -0.00897165946662426, -0.008417068049311638, 0.03075140155851841, -0.034854840487241745, 0.05095326527953148, 0.011072774417698383, 0.003693636739626527, 0.030792752280831337, 0.022014658898115158, 0.08125108480453491, -0.0018430993659421802, 0.013362754136323929, -0.014309272170066833, 0.04307541623711586, -0.0561082549393177, -0.04573824256658554, -0.05285949259996414, -0.004662231542170048, 0.04658126458525658, 0.009948131628334522, -0.0032997108064591885, 0.016380948945879936, -0.03294561058282852, 0.023286230862140656, -0.027665184810757637, -0.05566917732357979, 0.03299333527684212, 0.027854718267917633, 0.012440403923392296, 0.004048691131174564, 0.033778343349695206, 0.0007256946410052478, -0.012582298368215561, -0.0020326555240899324, -0.06982000917196274, -0.002764492528513074, 0.05952199921011925, -0.0014415126061066985, -0.007953835651278496, 0.013735122978687286, -0.04492732882499695, 0.027336206287145615, -0.03735746443271637, 0.03324989974498749, -0.007280372083187103, 0.04005298390984535, 0.011140668764710426, 0.03605363890528679, 0.04053351283073425, -0.026861725375056267, 0.013897759839892387, -0.01875409483909607, 0.014244443736970425, 0.03121175616979599, -0.020746730268001556, 0.009409510530531406, -0.013316169381141663, 0.01509831566363573, 0.07622839510440826, 0.029229842126369476, 0.04377307742834091, 0.022370636463165283, -0.039851102977991104, 0.0841573104262352, 0.028084663674235344, 0.02794049307703972, 0.021773742511868477, -0.011574178002774715, 0.06581724435091019, 0.08234963566064835, 0.026177583262324333, -0.036634840071201324, -0.01049058884382248, 0.015695784240961075, 0.017923705279827118, 0.06263067573308945, 0.0698830857872963, 0.05981609597802162, 0.04257066175341606, 0.019235650077462196, 0.020049095153808594, -0.05010908842086792, 0.00114496483001858, -0.047593194991350174, 0.04095514491200447, -0.0027382688131183386, -0.017970427870750427, 0.01013877708464861, -0.018991630524396896, 0.01591171883046627, -0.002064957981929183, -0.02050936594605446, -0.021353494375944138, -0.008094730786979198, 0.012832576408982277, 0.04443074390292168, 0.04563900828361511, -0.020527295768260956, -0.011164396069943905, 0.030562832951545715, -0.01869523525238037, 0.038232866674661636, 0.06211162731051445, 0.05357271432876587, -0.01487375982105732, -0.041265539824962616, 0.00046786884195171297, 0.04181664064526558, 0.013176453299820423, -0.002829670673236251, -0.024918876588344574, -0.008613954298198223, 0.04558269679546356, -0.04505271464586258, -0.01693037897348404, 0.02297447994351387, -0.07562929391860962, 0.0523994117975235, 0.0015176896704360843, -0.01610296033322811, -0.002899151761084795, -0.027218148112297058, -0.0377664640545845, -0.02646062709391117, -0.014054770581424236, 0.023246824741363525, -0.007086935918778181, 0.0645594671368599, -0.06226245313882828, -0.006063214503228664, -0.014185070060193539, -0.019128601998090744, -0.014342114329338074, -0.04068028926849365, -0.02212340757250786, 0.005958814639598131, 0.03847778961062431, -0.02033865451812744, -0.027318404987454414, 0.015190430916845798, -0.03149085119366646, -0.024597173556685448, 0.06556596606969833, 0.002504419069737196, 0.026369832456111908, 0.050860319286584854, -0.044913358986377716, 0.05339605361223221, -0.048207517713308334, 0.005989353638142347, 0.04282567650079727, -0.03861767053604126, 0.044224727898836136, -0.03803667426109314, 0.03459307923913002, 0.025622550398111343, 0.03179914876818657, 0.03708335757255554, 0.04387257248163223, -0.0013741498114541173, 0.00416902732104063, 0.013041140511631966, 0.009365926496684551, -0.02221130207180977, -0.007676160894334316, 0.007782269269227982, 0.028500203043222427, -0.04540463909506798, -0.003129845019429922, -0.02137119695544243, -0.07740095257759094, 0.00908949039876461, 0.04329991340637207, -0.007817141711711884, -0.05792980268597603, 0.07492104172706604, 0.005626569967716932, 0.0023122879210859537, 0.035593900829553604, -0.0021904991008341312, 0.05331723019480705, -0.04524176940321922, 0.045231740921735764, 0.04118337482213974, 0.03255245089530945, -0.05875225365161896, 0.01517565455287695, -0.015632353723049164, -0.018055826425552368, 0.001595840323716402, 0.03713833540678024, -0.06986043602228165, -0.0467795692384243, 0.024678604677319527, 0.01632249727845192, -0.04781496524810791, 0.028757687658071518, -0.08338087797164917, 0.01758534088730812, -0.011264738626778126, 0.021268272772431374, 0.09386846423149109, 0.040992267429828644, -0.0266200453042984, 0.01738659292459488, -0.02636515535414219, 0.029923725873231888, 0.04086736962199211, -0.0565013661980629, -0.024024158716201782, 0.04125343635678291, 0.028705758973956108, -0.05231969431042671, 0.05494169145822525, 0.011942722834646702, 0.005479901563376188, -0.006661645602434874, -0.006164648104459047, -0.007704492192715406, -0.01349847111850977, -0.04358479753136635, 0.014563778415322304, 0.043385446071624756, 0.009855933487415314, -0.05358687415719032, -0.03150026500225067, -0.07490224391222, -0.020636683329939842, -0.023039741441607475, 0.03397022560238838, -0.018411049619317055, -0.022094061598181725, -0.0628272220492363, -0.032323531806468964, -0.038930799812078476, -0.03556155785918236, 0.005137696862220764, 0.001010197913274169, 0.0495709553360939, 0.021375108510255814, 0.03758892044425011, -0.006340411026030779, 0.02117301896214485, -0.014940413646399975, -0.0036580876912921667, 0.0734470784664154, -0.009514869190752506, -0.02124650403857231, -0.049285102635622025, 0.010927541181445122, -0.008539064787328243, 0.015418320894241333, -0.037474051117897034, -0.05072028562426567, 0.03430281579494476, 0.03687664866447449, 0.0016951258294284344, -0.007692919112741947, 0.02933855541050434, -0.05163442716002464, 0.03277149796485901, 0.0018161560874432325, 0.06295445561408997, 0.03700912371277809, -0.051189813762903214, 0.016564233228564262, 0.001850104657933116, -0.05523497611284256, 0.034867025911808014, -0.009998590685427189, -0.019915608689188957, -0.015185418538749218, 0.023100335150957108, -0.07200491428375244, -0.018203964456915855, 0.004117194097489119, 0.046710774302482605, 0.0050460826605558395, 0.00860747043043375, -0.043723639100790024, 0.00209411489777267, 0.009063995443284512, 0.034003790467977524, -0.03228812292218208, -0.015336859971284866, 0.027065778151154518, -0.030756274238228798, 0.050459858030080795, -0.026942916214466095, 0.07351580262184143, 0.018470512703061104, 0.03230799362063408, 0.04020167887210846, -0.021711742505431175, -0.02173295058310032, -0.01546295266598463, -0.015597458928823471, 0.05199400708079338, 0.007322243880480528, 0.07818926870822906, -0.05390321835875511, -0.0696047991514206, 0.019967928528785706, 0.004910509567707777, 0.006741195451468229, 0.007670064456760883, 0.02117537334561348, 0.08086147904396057, 0.007908587343990803, -0.04157428815960884, 0.004684216808527708, 0.017221732065081596, -0.05949065461754799, 0.04946796968579292, 0.024985602125525475, -0.06771745532751083, -0.01479030679911375, -0.0436665304005146, -0.034285176545381546, -0.009856075048446655, -0.019666075706481934, 0.0019466698868200183, -0.018959837034344673, 0.0116347037255764, 0.05167950689792633, 0.008448170498013496, 0.0033036726526916027, 0.02761871926486492, 0.054973896592855453, 0.023439152166247368, 0.0268502589315176, 0.03483767434954643, 0.01560461800545454, 0.07468864321708679, 0.03385331109166145, 0.0395936444401741, -0.01772974245250225, 0.048395320773124695, -0.040159016847610474, 0.030514905229210854, -0.05442448705434799, -0.0237160362303257, -0.05708145722746849, -0.06437352299690247, -0.016794925555586815, -0.044191647320985794, -0.08034586161375046, -0.036257363855838776, -0.014706968329846859, 0.0020374038722366095, -0.011633329093456268, 0.056990206241607666, 0.031878434121608734, 0.05463844910264015, -0.04411407932639122, -0.014874109998345375, 0.037174589931964874, 0.0951949954032898, -0.03634722903370857, 0.009380877017974854, 0.035756807774305344, 0.03473912551999092, 0.05486726388335228, -0.03540579974651337, -0.027035601437091827, 0.018433937802910805, -0.023848412558436394, -0.03161109983921051, -0.025907112285494804, -0.030970498919487, 0.032481249421834946, 0.05746404081583023, 0.033101342618465424, 0.026481380686163902, -0.005235622636973858, -0.014886860735714436, -0.06538768857717514, 0.04217911139130592, 0.023094328120350838, -0.026243681088089943, -0.0062861368060112, -0.011004096828401089, 0.032678473740816116, 0.03922640532255173, 0.001118290121667087, -0.06491592526435852, -0.07188074290752411, 0.0019428074592724442, -0.038903214037418365, 0.0075483014807105064, -0.07855934649705887, 0.01369742676615715, -0.10367882251739502, 0.05175095796585083, -0.05607995018362999, -0.035421084612607956, -0.04430582374334335, 0.06121542304754257, 0.05413438752293587, -0.012752735055983067, -0.023879116401076317, 0.002481193747371435, 0.0012930971570312977, -0.02875891700387001, -0.07614603638648987, 0.019929561764001846, 0.0033562774769961834, 0.052738115191459656, 0.002299930201843381, 0.06126132607460022, -0.029456181451678276, 0.006907540839165449, -0.04872303083539009, 0.005966671276837587, 0.006869656965136528, -0.04716451093554497, 0.02242395281791687, -0.0982229933142662, 0.040258318185806274, 0.03227117657661438, -0.021943828091025352, -0.01581554487347603, 0.00134583271574229, 0.020532920956611633, -0.026069657877087593, 0.029985839501023293, 0.00031958406907506287, -0.029326273128390312, -0.046168264001607895, -0.03637007623910904, 0.03879488632082939, -0.024241270497441292, -0.036251991987228394, -0.04498083516955376, -0.03613932803273201, -0.008937858045101166, 0.03182872757315636, -0.00299494294449687, 0.03481130301952362, 0.040414270013570786, 0.034994903951883316, -0.013577518053352833, -0.0015498128486797214, 0.035522520542144775, -0.011658231727778912, 0.00441779987886548, -0.022151658311486244, 0.04042523354291916, -0.026339054107666016, -0.048549965023994446, 0.002380028832703829, 0.010511284694075584, -0.014409556984901428, -0.024578776210546494, 0.04770380258560181, -0.0021545891650021076, 0.018667466938495636, -0.02386273443698883, 0.020695552229881287, 0.018783340230584145, -0.021549925208091736, 0.004722157027572393, 0.0051843347027897835, -0.08999639749526978, 0.015203255228698254, 0.014799139462411404, -0.048213809728622437, 0.015176250599324703, 0.014845121651887894, -0.06401092559099197, 0.015419282019138336, -0.0009915708797052503, 0.08178169280290604, -0.050902459770441055, 0.005393375642597675, -0.02247639372944832, -0.03686312213540077, 0.019735997542738914, 0.01262830849736929, 0.0017432351596653461, 0.021371103823184967, 0.05835340917110443, -0.01661759428679943, 0.021706251427531242, -0.0038509885780513287, 0.018827317282557487, 0.011544978246092796, 0.01719481684267521, -0.06337912380695343, 0.00497474055737257, 0.051138486713171005, 0.013737538829445839, -0.02233707532286644, 0.017177153378725052, -0.02130347117781639, -0.024097906425595284, -0.06233140453696251, -0.02659817971289158, 0.017233289778232574, -0.028843248263001442, -0.05710560455918312, -0.020458389073610306, -0.09203100204467773, -0.01194185670465231, -0.022766629233956337, 0.06380026787519455, -0.017850007861852646, 0.002749535022303462, 0.004179151263087988, 0.05086004361510277, -0.026453319936990738, 0.021388744935393333, 0.01228278037160635, 0.06528982520103455, -0.00995821412652731, 0.054835014045238495, -0.007963677868247032, -0.06316812336444855, 0.0020074830390512943, 0.019664546474814415, 0.018269235268235207, 0.00849667377769947, -0.0024067284539341927, 0.009558060206472874, 0.04245254769921303, -0.04047213867306709, 0.032628800719976425, 0.031452737748622894, -0.009492071345448494, 0.041012078523635864, -0.0027374376077204943, -0.027560429647564888, 0.039448391646146774, 0.007364786695688963, 0.04336561635136604, 0.01588083617389202, -0.020963601768016815, -0.04098694026470184, -0.03435163572430611, -0.036630671471357346, -0.024444852024316788, 0.018309449777007103, 0.010371615178883076, 0.07495571672916412, -0.020027922466397285, 0.05977759137749672, 0.02220497652888298, 0.05261988937854767, 0.015489768236875534, -0.005632407497614622, 0.02270667999982834, 0.003341550473123789, 0.01999855414032936, -0.004781623370945454, 0.0022169791627675295, -0.02827371284365654, -0.014400581829249859, 0.05840599164366722, -0.01321793906390667, -0.035642944276332855, -0.07503771781921387, 0.022724298760294914, -0.03745904192328453, -0.04171173274517059, -0.03450438752770424, 0.07084275782108307, 0.04435300827026367, 0.030247215181589127, -0.02462858147919178, 0.052653707563877106, 0.010972459800541401, -0.016242703422904015, 0.09729332476854324, -0.005419723689556122, -0.011234985664486885, -0.016403520479798317, 0.03774973377585411, -0.03567562624812126, -0.0259556882083416, 0.02610950358211994, -0.0002977205440402031, -0.08402026444673538, -0.0005467110895551741, 0.06339220702648163, -0.0010702558793127537, 0.014253403060138226, 0.08673804253339767, 0.03959492966532707, -0.0746275782585144, 0.014785554260015488, 0.0037420776207000017, -0.02982337214052677, -0.003820269601419568, -0.00423947349190712, 0.027281461283564568, -0.013890305534005165, 0.018429219722747803, -0.0011182980379089713, -0.03776165843009949, 0.025309333577752113, -0.028577689081430435, -0.0686303898692131, 0.04895767942070961, -0.01305493712425232, 0.009527651593089104, -0.020902099087834358, -0.01713995449244976, -0.03891129419207573, -0.07550188899040222, -0.04298461601138115, 0.006605065893381834, -0.07890760898590088, 0.0263650082051754, 0.11085960268974304, 0.013421213254332542, 0.03257889673113823, 0.025348840281367302, -0.020981360226869583, 0.0014824229292571545, 0.015212095342576504, 0.05155026540160179, -0.006620828993618488, -0.03600949048995972, -0.016380129382014275, -0.008427128195762634, 0.0008437851211056113, 0.02881995216012001, 0.03329569846391678, -0.0039413790218532085, -0.01361809577792883, -0.026802316308021545, 0.01811249740421772, -0.03508793190121651, -0.042718321084976196, -0.02966846339404583, 0.05761295184493065, -0.00540443230420351, -0.004095961805433035, 0.00018651297432370484, -0.015066529624164104, 0.053506121039390564, -0.007835784927010536, -0.017855204641819, -0.019117051735520363, 0.006068281829357147, -0.020093999803066254, 0.02268475666642189, -0.0009749950258992612, 0.04025373235344887, 0.03627001866698265, 0.028113359585404396, 0.029240760952234268, -0.0167478546500206, -0.08822352439165115, -0.021914422512054443, -0.004269516561180353, -0.04553765803575516, -0.018596896901726723, -0.020846709609031677, -0.038466569036245346, 0.06772693246603012, 0.004669505171477795, -0.02088693343102932, 0.06366957724094391, -0.05066429078578949, -0.021664997562766075, 0.03412799909710884, -0.04542582109570503, 0.002664515282958746, -0.02486547827720642, -0.02011955715715885, 0.08855610340833664, -0.011232755146920681, 0.0039499616250395775, 0.029799573123455048, -0.037833236157894135, 0.05545744299888611, 0.032455913722515106, 0.025281934067606926, -0.05368201062083244, -0.033937718719244, -0.05077020823955536, -0.020518949255347252, 0.0012743136612698436, 0.021833032369613647, 0.0033026181627064943, -0.029647458344697952, 0.010515235364437103, -0.0033429511822760105, -0.01637299358844757, -0.02762429229915142, -0.0683092400431633, 0.05125931277871132, -0.01765558309853077, 0.03378241881728172, 0.04970979690551758, -0.040932025760412216, 0.012243757024407387, 0.028251366689801216, 0.001717491541057825, 0.02109183557331562, -0.041697464883327484, 0.0214995164424181, -0.01663195714354515, 0.025778094306588173, 0.017976824194192886, -0.01074167713522911, 0.00020131452765781432, 0.010260003618896008]


import numpy as np

consine_similarity = np.dot(queryEMbedding,contextEMbedding)/(np.linalg.norm(queryEMbedding)*np.linalg.norm(contextEMbedding))
print(consine_similarity)
# Out:
# 0.7678051362715217
